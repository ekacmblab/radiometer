# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /Users/cosmology/radiometer/ReadoutApp/Data/
# Out:
# /Users/cosmology/radiometer/ReadoutApp/Data

# %%
data = np.loadtxt('2017-09-15_14:22:49longdata.txt')

# %%
data.shape
# Out:
# (2966, 3)

# %%
time = data[:, 0]

# %%
brightness = data[:, 1]

# %%
temperature = data[:, 2]

# %%
mabitbol15@gmail.com
# Out:
#   File "<ipython-input-8-2611c6c3d8d1>", line 1
#     mabitbol15@gmail.com
#               ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
# 2017-09-15_13:58:09day1test.txt        2017-09-15_14:56:14testing_paddle.txt
# 2017-09-15_14:22:49longdata.txt        Old Data/
# 2017-09-15_14:55:46testing_paddle.txt  linearity/

# %%
data_paddle = np.loadtxt("2017-09-15_14:56:14testing_paddle.txt")

# %%
time_paddle = data_paddle[:, 0]

# %%
brightness_paddle = data_paddle[:, 1]

# %% [raw]
# temp_paddle = data_paddle[:, 2]

# %%
temp_paddle = data_paddle[:, 2]

# %%
plot(time_paddle-time_paddle[0], brightness_paddle)

# %%
np.std(brightness_paddle) / np.mean(brightness_paddle) * 100
# Out:
# 0.095505986508562804

# %%
data_styro = np.loadtxt("2017-09-15_15:04:23styro_paddle.txt")

# %%
time_styro = data_styro[:, 0]

# %%
brightness_styro = data_styro[:, 1]

# %%
temp_styro = data_styro[:, 2]

# %%
plot(time_styro - time_styro[0], brightness_styro)

# %%
np.std(brightness_styro) / np.mean(brightness_styro) * 100
# Out:
# 0.097768059121684681

# %%
np.mean(brightness_styro)
# Out:
# 0.11217063973063973

# %%
np.mean(brightness_paddle)
# Out:
# 0.111654012137559

# %%
data_fill = np.loadtxt("2017-09-15_15:11:51filledbox.txt")

# %%
time_fill = data_fill[:, 0]

# %%
brightness_fill = data_fill[:, 1]

# %%
temp_fill = data_fill[:, 2]

# %%
plot(time_fill-time_fill[0], brightness_fill)

# %%
np.std(brightness_fill) / np.mean(brightness_fill) * 100
# Out:
# 0.094217138218477894

# %%
np.mean(brightness_fill)
# Out:
# 0.11108408631153067

# %%
np.mean(brightness)
# Out:
# 0.11347950101146323

# %%
np.std(brightness) / np.mean(brightness) * 100
# Out:
# 0.27745690357018959

# %%
plot(time-time[0], brightness)

# %%
plot(time_fill-time_fill[0], temp_fill)

# %%
np.std(temp_fill) / np.mean(temp_fill) * 100
# Out:
# 0.020424325292208764

# %%
plot(time_styro-time_styro[0], temp_styro)

# %%
plot(time_paddle-time_paddle[0], temp_paddle)

# %%
x = np.arange(10)

# %%
plot(x)
