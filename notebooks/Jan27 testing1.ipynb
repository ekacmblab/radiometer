# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import time
import visa

# %%
rm = visa.ResourceManager()
print(rm.list_resources())
# Out:
# (u'USB0::0x0957::0x0618::MY52210065::INSTR', u'ASRL1::INSTR')

# %%
multimeter = rm.open_resource('USB0::0x0957::0x0618::MY52210065::INSTR')
print(multimeter.query('*IDN?'))
# Out:
# Agilent Technologies,34405A,MY52210065,1.47-3.13

# %%
print(multimeter.query("READ?"))
# Out:
# +1.44200000E-01

# %%
data = []
t = []
t0 = time.time()
for k in range(1000):
    t.append(time.time())
    data.append(multimeter.query_ascii_values("READ?")[0])

# %%
plot(t, data, '.')

# %%
data3 = []
t3 = []
t0 = time.time()
for k in range(1000):
    t3.append(time.time())
    data3.append(multimeter.query_ascii_values("READ?")[0])

# %%
plot(t3, data3, '.')

# %%
plot(t, data, '.')
plot(t2,data2, '.')
plot(t3, data3, '.')
