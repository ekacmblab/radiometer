# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../MevJosCode/Data/
# Out:
# /Users/cosmology/radiometer/MevJosCode/Data

# %%
import glob

# %%
filenames = glob.glob('*.txt')

# %%
filenames
# Out:
# ['2017-02-17_14:20:32_Readout.txt',
#  '2017-02-17_14:24:37_Readout.txt',
#  '2017-02-17_14:53:03_Readout.txt',
#  '2017-02-17_14:54:29_Readout.txt',
#  '2017-02-17_14:56:03_Readout.txt',
#  '2017-02-17_14:57:30_Readout.txt',
#  '2017-02-17_14:59:57_Readout.txt',
#  '2017-02-17_15:02:19_Readout.txt',
#  '2017-02-17_15:03:55_Readout.txt',
#  '2017-02-17_15:06:03_Readout.txt',
#  '2017-02-17_15:08:13_Readout.txt',
#  '2017-02-17_15:10:18_Readout.txt',
#  '2017-02-17_15:15:37_Readout.txt',
#  '2017-02-17_15:18:00_Readout.txt',
#  '2017-02-17_15:19:45_Readout.txt',
#  '2017-02-17_15:22:34_Readout.txt',
#  '2017-02-17_15:25:07_Readout.txt',
#  '2017-02-17_15:26:29_Readout.txt',
#  '2017-02-17_15:28:41_Readout.txt',
#  '2017-02-17_15:31:04_Readout.txt',
#  '2017-02-17_15:32:38_Readout.txt',
#  '2017-02-17_15:34:44_Readout.txt',
#  '2017-02-17_15:36:12_Readout.txt',
#  '2017-02-17_15:38:29_Readout.txt',
#  '2017-02-17_15:39:52_Readout.txt',
#  '2017-02-17_15:42:39_Readout.txt',
# ...

# %%
filenames = filenames[2:]

# %%
for f in filenames:
    x = np.loadtxt(f)
    if len(x):
        if np.median(x[:,1]) < 0.2:
            x[:,1] *= 10
        plot(x[:,0], x[:,1])

# %%
x = np.loadtxt(filenames[6])
plot(x[:,0], x[:,1])

# %%
csvf = glob.glob('*.csv')

# %%
csvf
# Out:
# ['Data_Sheet.csv']

# %%
x = np.cs(csvf[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-4968598851c5> in <module>()
# ----> 1 x = np.loadtxt(csvf[0])
#
# /Users/cosmology/anaconda2/envs/radiometer/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# /Users/cosmology/anaconda2/envs/radiometer/lib/python2.7/site-packages/numpy/lib/npyio.pyc in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
x = np.loadtxt(filenames[0])

# %%
plot(x[:,0], x[:,1])

# %%
plot(x[:,0], x[:,2])

# %%
x = np.arange(100)
plot(x, x*x)
